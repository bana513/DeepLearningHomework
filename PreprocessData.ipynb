# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

from numpy import genfromtxt
data = genfromtxt('poloniex_usdt_btc_20170101_DOHLCV_300.csv', delimiter=';')
data.astype("float16")

# with open('poloniex_usdt_btc_20160101_DOHLCV_300.csv', 'r') as f:
#     reader = csv.reader(f,delimiter=';')
    
#     for line in reader:
#         data = np.append(data, line)

# print(data[:10])
plt.figure(figsize=(18, 5))
plt.subplot(311).set_title('First 1000 candles - close')
plt.plot(data[:1000,4])
plt.subplot(312).set_title('1000 candles in the middle - close')
plt.plot(data[50000:51000,4])
plt.subplot(313).set_title('Last 1000 candles - close')
plt.plot(data[-1000:,4])
plt.show()
